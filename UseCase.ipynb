# %% [markdown]
# # Dynamically pin and unpin from providers
# ## Benefit
# * Data Scientists can dynamically change pinning providers
# * Data Scientists don't rely on one IPFS gateway, but can use many

# %% [markdown]
# ## Importing libraries

# %%
#main protocol
from storage.ipfs import IPFS

#pinning providers
from storage.nftstorage import NFTStorage
from storage.pinataV1 import PinataV1


#helpers
from helpers.helper import read_file
import pandas as pd

# %%
#Load in credentials - Not an optimal solution and can investigate a better solution with something like Lit Protocol

nft_storage = NFTStorage()
nft_storage_creds = nft_storage.get_creds()
ipfs = IPFS()
pinata = PinataV1()
pinata_creds = pinata.get_creds()

# %%
#Upload to nft storage, this is called pinning or simplicity, NFTstorage actually facilitates the pinning deals under the hood inteh deals section
#the response returns a cid and what filecoin deals have been made to pin your file.

response, status_code = nft_storage.upload_file(nft_storage_creds,"dataset/sample/ens_airdrop.json")

pd.DataFrame(response)
# Out:
#            ok                                              value
# cid      True  bafybeiek3lyobn6lgt46bj5pf4cyd7qcj7o4umkeyg7rv...
# created  True                      2022-03-09T02:21:11.461+00:00
# deals    True  [{'status': 'active', 'lastChanged': '2022-03-...
# files    True                                                 []
# pin      True  {'cid': 'bafybeiek3lyobn6lgt46bj5pf4cyd7qcj7o4...
# scope    True                                       audiocentive
# size     True                                           42725339
# type     True                                          form-data

# %%
#Pin to pinata for redundency
pinata.pin(pinata_creds,response["value"]["cid"],fn="ens_airdrop.json")
# Out:
# ({'id': '2b67e49a-f8ca-4771-a25e-7851ccce8e47',
#   'ipfsHash': 'bafybeiek3lyobn6lgt46bj5pf4cyd7qcj7o4umkeyg7rvwkpjfr6tsj3ye',
#   'status': 'prechecking',
#   'name': 'ens_airdrop.json'},
#  200)

# %%
#Check the status of the pinning job, pin policy will show what regions the file is available in
params = {"hashContains":"DESC","status":None,"prechecking":None,
          "searching":None,"retrieving":None,
          "expired":None,"over_free_limit":None,
          "over_max_size":None,"invalid_object":None,
          "bad_host_node":None,"ipfs_pin_hash":response["value"]["cid"],
          "limit":None,"offset":None,"metadata[name]":None,
          "metadatakeyvalues":"keyvalues"
         }

pinata.get_pinned_jobs(pinata_creds,params)
# Out:
# ({'count': 1,
#   'rows': [{'id': '2b67e49a-f8ca-4771-a25e-7851ccce8e47',
#     'ipfs_pin_hash': 'bafybeiek3lyobn6lgt46bj5pf4cyd7qcj7o4umkeyg7rvwkpjfr6tsj3ye',
#     'date_queued': '2022-03-29T17:27:12.618Z',
#     'name': 'ens_airdrop.json',
#     'status': 'prechecking',
#     'keyvalues': {},
#     'host_nodes': None,
#     'pin_policy': {'regions': [{'id': 'NYC1', 'desiredReplicationCount': 1}],
#      'version': 1}}]},
#  200)

# %%
"""
Query Parameters = params

hashContains: (string) - Filter on alphanumeric characters inside of pin hashes. Hashes which do not include the characters passed in will not be returned.

pinStart: (must be in ISO_8601 format) - Exclude pin records that were pinned before the passed in "pinStart" datetime.

pinEnd: (must be in ISO_8601 format) - Exclude pin records that were pinned after the passed in "pinEnd" datetime.

unpinStart: (must be in ISO_8601 format) - Exclude pin records that were unpinned before the passed in "unpinStart" datetime.

unpinEnd: (must be in ISO_8601 format) - Exclude pin records that were unpinned after the passed in "unpinEnd" datetime.

pinSizeMin: (integer) - The minimum byte size that pin record you're looking for can have

pinSizeMax: (integer) - The maximum byte size that pin record you're looking for can have

status: (string) -
    * Pass in "all" for both pinned and unpinned records
    * Pass in "pinned" for just pinned records (hashes that are currently pinned)
    * Pass in "unpinned" for just unpinned records (previous hashes that are no longer being pinned on pinata)

pageLimit: (integer) - This sets the amount of records that will be returned per API response. (Max 1000)

pageOffset: (integer) - This tells the API how far to offset the record responses. For example, 
if there's 30 records that match your query, and you passed in a pageLimit of 10, providing a pageOffset of 10 would return records 11-20.
"""

#Get all pinned files to unpin and then pin in NFT Storage
#If pageLimit == None then defaults to most recent 10

params = {"hasContains":"b","pinStart":None,
          "pinEnd":None,"unpinStart":None,
          "unpinEnd":None,"pinSizeMin":None,
          "pinSizeMax":None,"status":None,
          "pageLimit":100,"pageOffset":None,
         }

pf,status = pinata.get_pinned_files(pinata_creds,params)
df_pinata = pd.DataFrame(pf["rows"])

df_pinata.drop_duplicates(["ipfs_pin_hash"])
# Out:
#                                       id  \
# 0   0612d1c0-4898-4aee-a3b6-75c6447c1ae4
# 1   68549d6a-0d44-46e3-afdb-bb9b5d9916b1
# 2   77a58afd-7646-4e32-a751-9866fe5d71b5
# 3   1802cebc-d351-4b35-854a-bf82bc89e7e1
# 4   bc0dcbf9-bf81-41bc-a166-4c34ac876d74
# 5   3d6b6f57-3309-4db7-8688-2c9eed53df2b
# 6   28a0cbd2-dd21-45da-bbb7-a65a96d49273
# 7   8582eda6-4939-4dce-b309-5ab18122fc03
# 8   b6207faf-9e90-419c-bb44-c509f0547d80
# 34  a7bc087e-6748-4be5-aae6-e420aabeefe3
# 45  c3106d6e-d8f6-4d4f-8186-93f89d8e8f15
# 46  838cd171-f6c6-40a7-beec-899ca8acb66d
# 67  07134094-e046-4935-95a5-ef4cca4cec09
# 70  85059d99-318e-4b44-99b6-975b75c99acb
# 72  926f2e41-2420-4535-82c9-14e9f244a435
# 73  721300ed-fd44-43ef-87a4-9ed2c3c3e2b9
#
#                                         ipfs_pin_hash      size  \
# 0      QmNN12xSayeJ7m3yz5bK4bVb4rJ4cr8WS6EcNeMKDcfZsE   6455753
# 1      QmWvvVY9meNZ6b6UXr8Vy7J2Z4eSS4YpPJ5nyrgfd7ZFMP      2290
# 2      QmewtgEqcXHLDgCt7oEahyjEyxb63sVkskhypeUVKsNnv6       906
# 3      QmQxh7mQhpuCCSt7ryU2MCqc4zdoxVQfSJF4Mun2AUTVqd      2130
# 4      QmQwwMbykhX3wyCdC5yBRXV4JQRe5FFLiyynaUiLbmvLzn     10013
# 5      QmRxu3HoofyTntXhCSXBv98tPDWLdgNee32Z1nMQcCbxU7      1640
# 6      QmWAQjxm6CKaAjHjwPSqWmN8RMecuHS1bxEufqCNVSq96e   5985301
# 7      QmZ8bNMNXodiWRJDvDHNCAE1EsnbaiTZaQJafm2pSTYBFh      9887
# 8   bafybeiek3lyobn6lgt46bj5pf4cyd7qcj7o4umkeyg7rv...  42725339
# 34  bafybeif6gdxdpleultgqobk65dhy6gvnozu27a3lbm4xw...   6455453
# 45  bafkreiesap4b4a4xgvfxhsz6hdza7atezclk4op3iz5lu...     23597
# 46  bafkreief472lhr6b54baq4oansiwor4ed2te2xztwgjqe...     24858
# 67  bafybeie4yihf42kahspmhqkmovpxt2iliqqikbriwsglb...   5985025
# 70  bafkreie2muwin7je3fc5uaepmc6jwt6mv6mfxiiwbm2yn...       895
# 72     QmRE9W9efQjWgb9rABf4gU2SG48aabfvApUYJJBFE1BSzP      2350
# 73  bafybeif36uqfqj5on23qfdl3nglc7ncgcbnz4ixpleoms...   2086898
#
#                                  user_id               date_pinned  \
# 0   d28f20cf-dfe0-4c8f-9272-26b9c2d8a3cd  2022-03-29T17:16:19.279Z
# 1   d28f20cf-dfe0-4c8f-9272-26b9c2d8a3cd  2022-03-29T17:16:16.868Z
# 2   d28f20cf-dfe0-4c8f-9272-26b9c2d8a3cd  2022-03-29T17:16:15.378Z
# 3   d28f20cf-dfe0-4c8f-9272-26b9c2d8a3cd  2022-03-29T17:16:14.251Z
# 4   d28f20cf-dfe0-4c8f-9272-26b9c2d8a3cd  2022-03-29T17:12:54.152Z
# 5   d28f20cf-dfe0-4c8f-9272-26b9c2d8a3cd  2022-03-29T17:12:53.285Z
# 6   d28f20cf-dfe0-4c8f-9272-26b9c2d8a3cd  2022-03-29T17:07:33.557Z
# 7   d28f20cf-dfe0-4c8f-9272-26b9c2d8a3cd  2022-03-29T17:07:32.265Z
# 8   d28f20cf-dfe0-4c8f-9272-26b9c2d8a3cd  2022-03-29T17:07:32.058Z
# 34  d28f20cf-dfe0-4c8f-9272-26b9c2d8a3cd  2022-03-29T03:07:22.902Z
# 45  d28f20cf-dfe0-4c8f-9272-26b9c2d8a3cd  2022-03-24T16:56:19.857Z
# 46  d28f20cf-dfe0-4c8f-9272-26b9c2d8a3cd  2022-03-24T16:54:09.843Z
# 67  d28f20cf-dfe0-4c8f-9272-26b9c2d8a3cd  2022-03-22T16:41:14.560Z
# 70  d28f20cf-dfe0-4c8f-9272-26b9c2d8a3cd  2022-03-20T23:39:06.751Z
# 72  d28f20cf-dfe0-4c8f-9272-26b9c2d8a3cd  2022-03-11T20:20:00.213Z
# 73  d28f20cf-dfe0-4c8f-9272-26b9c2d8a3cd  2022-03-11T02:14:04.863Z
#
#                date_unpinned  \
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# 5                       None
# 6                       None
# 7                       None
# 8                       None
# 34                      None
# 45                      None
# 46                      None
# 67  2022-03-28T22:26:17.486Z
# 70  2022-03-28T22:26:22.439Z
# 72  2022-03-28T22:26:38.124Z
# 73  2022-03-28T22:26:42.716Z
#
#                                              metadata  \
# 0                     {'name': None, 'keyvalues': {}}
# 1                     {'name': None, 'keyvalues': {}}
# 2                     {'name': None, 'keyvalues': {}}
# 3                     {'name': None, 'keyvalues': {}}
# 4                     {'name': None, 'keyvalues': {}}
# 5                     {'name': None, 'keyvalues': {}}
# 6   {'name': 'compound.csv', 'keyvalues': {'DAO': ...
# 7                     {'name': None, 'keyvalues': {}}
# 8                     {'name': None, 'keyvalues': {}}
# 34              {'name': 'aave.csv', 'keyvalues': {}}
# 45  {'name': 'Popcorn Limited - Dune Dashboards - ...
# 46  {'name': 'Popcorn Limited - Dune Dashboards - ...
# 67          {'name': 'compound.csv', 'keyvalues': {}}
# 70    {'name': 'reddituserlist.txt', 'keyvalues': {}}
# 72             {'name': 'storage', 'keyvalues': None}
# 73  {'name': 'test.py', 'keyvalues': {'0': 'newKey...
#
#                                               regions
# 0   [{'regionId': 'NYC1', 'currentReplicationCount...
# 1   [{'regionId': 'NYC1', 'currentReplicationCount...
# 2   [{'regionId': 'NYC1', 'currentReplicationCount...
# 3   [{'regionId': 'NYC1', 'currentReplicationCount...
# 4   [{'regionId': 'NYC1', 'currentReplicationCount...
# 5   [{'regionId': 'NYC1', 'currentReplicationCount...
# 6   [{'regionId': 'NYC1', 'currentReplicationCount...
# 7   [{'regionId': 'NYC1', 'currentReplicationCount...
# 8   [{'regionId': 'NYC1', 'currentReplicationCount...
# 34  [{'regionId': 'NYC1', 'currentReplicationCount...
# 45  [{'regionId': 'NYC1', 'currentReplicationCount...
# 46  [{'regionId': 'NYC1', 'currentReplicationCount...
# 67  [{'regionId': 'NYC1', 'currentReplicationCount...
# 70  [{'regionId': 'NYC1', 'currentReplicationCount...
# 72  [{'regionId': 'NYC1', 'currentReplicationCount...
# 73  [{'regionId': 'NYC1', 'currentReplicationCount...

# %%
df_pinata.query('ipfs_pin_hash == "QmWAQjxm6CKaAjHjwPSqWmN8RMecuHS1bxEufqCNVSq96e"')["metadata"]
# Out:
# 6     {'name': 'compound.csv', 'keyvalues': {'DAO': ...
# 13    {'name': 'compound.csv', 'keyvalues': {'DAO': ...
# 14    {'name': 'compound.csv', 'keyvalues': {'DAO': ...
# 15          {'name': 'compound.csv', 'keyvalues': None}
# 16          {'name': 'compound.csv', 'keyvalues': None}
# Name: metadata, dtype: object

# %%
#Make a CID dictionary to pin these files to NFT Storage

df_pinata["filename"]=df_pinata["metadata"].apply(lambda x: x["name"])
file_dict = df_pinata[["filename","ipfs_pin_hash"]].drop_duplicates(subset="filename").set_index("filename")

file_dict = file_dict.drop(index=["Popcorn Limited - Dune Dashboards - 03242022.pdf","Popcorn Limited - Dune Dashboards - 03182022.pdf"])

file_dict
# Out:
#                                                                              ipfs_pin_hash
# filename
# None                                        QmNN12xSayeJ7m3yz5bK4bVb4rJ4cr8WS6EcNeMKDcfZsE
# compound.csv                                QmWAQjxm6CKaAjHjwPSqWmN8RMecuHS1bxEufqCNVSq96e
# aave2.csv                                   QmNN12xSayeJ7m3yz5bK4bVb4rJ4cr8WS6EcNeMKDcfZsE
# aave.csv                                 bafybeif6gdxdpleultgqobk65dhy6gvnozu27a3lbm4xw...
# ens_airdrop.json                         bafybeiek3lyobn6lgt46bj5pf4cyd7qcj7o4umkeyg7rv...
# All_Gateway_Properties.csv                  QmQwwMbykhX3wyCdC5yBRXV4JQRe5FFLiyynaUiLbmvLzn
# dataset                                     QmQwwMbykhX3wyCdC5yBRXV4JQRe5FFLiyynaUiLbmvLzn
# yes                                         QmZ8bNMNXodiWRJDvDHNCAE1EsnbaiTZaQJafm2pSTYBFh
# Popcorn - Dune Dashboards - 03182022.md     QmQxh7mQhpuCCSt7ryU2MCqc4zdoxVQfSJF4Mun2AUTVqd
# top600_usernames_notfound.txt               QmewtgEqcXHLDgCt7oEahyjEyxb63sVkskhypeUVKsNnv6
# reddituserlist.txt                       bafkreie2muwin7je3fc5uaepmc6jwt6mv6mfxiiwbm2yn...
# storage                                     QmRxu3HoofyTntXhCSXBv98tPDWLdgNee32Z1nMQcCbxU7
# test.py                                  bafybeif36uqfqj5on23qfdl3nglc7ncgcbnz4ixpleoms...
# happy.py                                    QmWvvVY9meNZ6b6UXr8Vy7J2Z4eSS4YpPJ5nyrgfd7ZFMP

# %%
#NFT Storage Files

response = nft_storage.get_all_files(nft_storage_creds)

nft_storage_files = pd.DataFrame(response.json()["value"])

nft_storage_files
# Out:
#                                                  cid  \
# 0  bafkreiesap4b4a4xgvfxhsz6hdza7atezclk4op3iz5lu...
# 1  bafkreief472lhr6b54baq4oansiwor4ed2te2xztwgjqe...
# 2  bafybeif6gdxdpleultgqobk65dhy6gvnozu27a3lbm4xw...
# 3  bafkreifhvosw3d4agsnduodmyupqdngsjdddobi5altxt...
# 4  bafkreie2muwin7je3fc5uaepmc6jwt6mv6mfxiiwbm2yn...
# 5  bafkreicwnshhm5jg6uvf6lvfcebohrijpyb6srz2vu2mj...
# 6  bafybeibjwiqi4c7yebpobalni3eijfgkgwmidbuyacyz6...
# 7  bafybeif36uqfqj5on23qfdl3nglc7ncgcbnz4ixpleoms...
# 8  bafybeihngw4os7fg6xzthb7cpydfiavpufkg746khabkc...
# 9  bafybeifxdk6cm6xecwyq7euxojpiuao66ob3nkbjjpxhh...
#
#                          created             type         scope  \
# 0  2022-03-24T16:55:42.506+00:00        form-data  audiocentive
# 1  2022-03-24T16:51:43.101+00:00        form-data  audiocentive
# 2  2022-03-22T17:04:21.124+00:00        form-data  audiocentive
# 3   2022-03-21T15:57:38.91+00:00  application/car       session
# 4  2022-03-20T23:33:25.689+00:00        form-data  audiocentive
# 5  2022-03-09T06:19:39.874+00:00        form-data  audiocentive
# 6   2022-03-09T04:10:04.14+00:00       image/jpeg  audiocentive
# 7  2022-03-09T04:03:21.867+00:00        form-data  audiocentive
# 8  2022-03-09T03:16:57.338+00:00        directory  audiocentive
# 9  2022-03-09T02:31:11.692+00:00        form-data  audiocentive
#
#                               files      size  \
# 0                                []     23597
# 1                                []     24858
# 2                                []   6455453
# 3                                []      2119
# 4                                []       895
# 5                                []     10060
# 6                                []   5245419
# 7                                []   2086898
# 8  [{'name': 'myfile', 'type': ''}]  42725396
# 9                                []  42725615
#
#                                                  pin  \
# 0  {'cid': 'bafkreiesap4b4a4xgvfxhsz6hdza7atezclk...
# 1  {'cid': 'bafkreief472lhr6b54baq4oansiwor4ed2te...
# 2  {'cid': 'bafybeif6gdxdpleultgqobk65dhy6gvnozu2...
# 3  {'cid': 'bafkreifhvosw3d4agsnduodmyupqdngsjddd...
# 4  {'cid': 'bafkreie2muwin7je3fc5uaepmc6jwt6mv6mf...
# 5  {'cid': 'bafkreicwnshhm5jg6uvf6lvfcebohrijpyb6...
# 6  {'cid': 'bafybeibjwiqi4c7yebpobalni3eijfgkgwmi...
# 7  {'cid': 'bafybeif36uqfqj5on23qfdl3nglc7ncgcbnz...
# 8  {'cid': 'bafybeihngw4os7fg6xzthb7cpydfiavpufkg...
# 9  {'cid': 'bafybeifxdk6cm6xecwyq7euxojpiuao66ob3...
#
#                                                deals
# 0  [{'status': 'active', 'lastChanged': '2022-03-...
# 1  [{'status': 'active', 'lastChanged': '2022-03-...
# 2  [{'status': 'active', 'lastChanged': '2022-03-...
# 3  [{'status': 'active', 'lastChanged': '2022-03-...
# 4  [{'status': 'active', 'lastChanged': '2022-03-...
# 5  [{'status': 'active', 'lastChanged': '2022-03-...
# 6  [{'status': 'active', 'lastChanged': '2022-03-...
# 7  [{'status': 'active', 'lastChanged': '2022-03-...
# 8  [{'status': 'active', 'lastChanged': '2022-03-...
# 9  [{'status': 'active', 'lastChanged': '2022-03-...

# %% [markdown]
# # Compare Pinata Files to NFT Storage to upload the outstanding files

# %%
pinata_pinned = file_dict["ipfs_pin_hash"].to_list()

nft_storage_pinned = nft_storage_files["cid"].to_list()

outstanding_hashs = set(nft_storage_pinned).difference(pinata_pinned)
outstanding_hashs
# Out:
# {'bafkreicwnshhm5jg6uvf6lvfcebohrijpyb6srz2vu2mjohji2xsitmv2y',
#  'bafkreief472lhr6b54baq4oansiwor4ed2te2xztwgjqez2btrns5d6dxi',
#  'bafkreiesap4b4a4xgvfxhsz6hdza7atezclk4op3iz5lusu5xxx7542ns4',
#  'bafkreifhvosw3d4agsnduodmyupqdngsjdddobi5altxtrexwxootuibme',
#  'bafybeibjwiqi4c7yebpobalni3eijfgkgwmidbuyacyz6hawfkrporatpi',
#  'bafybeifxdk6cm6xecwyq7euxojpiuao66ob3nkbjjpxhh4s2nwppwzgjuq',
#  'bafybeihngw4os7fg6xzthb7cpydfiavpufkg746khabkcgt7ig355n46ka'}

# %%
#Pin oustanding hashes to pinata
for cid in outstanding_hashs:
    
    pinata.pin(pinata_creds,cid)

# %%
#Pin oustanding hashes to pinata

for cid in outstanding_hashs:
    pinata.unpin(pinata_creds,cid)
    nft_storage.unpin(nft_storage_creds,cid)

# %% [markdown]
# # As you can see all the CIDs with a Q were removed. Q is V1 and b is V2

# %%
response = nft_storage.get_all_files(nft_storage_creds)

nft_storage_files = pd.DataFrame(response.json()["value"])

nft_storage_files
# Out:
#                                                  cid  \
# 0  bafkreiesap4b4a4xgvfxhsz6hdza7atezclk4op3iz5lu...
# 1  bafkreief472lhr6b54baq4oansiwor4ed2te2xztwgjqe...
# 2  bafybeif6gdxdpleultgqobk65dhy6gvnozu27a3lbm4xw...
# 3  bafkreifhvosw3d4agsnduodmyupqdngsjdddobi5altxt...
# 4  bafkreie2muwin7je3fc5uaepmc6jwt6mv6mfxiiwbm2yn...
# 5  bafkreicwnshhm5jg6uvf6lvfcebohrijpyb6srz2vu2mj...
# 6  bafybeibjwiqi4c7yebpobalni3eijfgkgwmidbuyacyz6...
# 7  bafybeif36uqfqj5on23qfdl3nglc7ncgcbnz4ixpleoms...
# 8  bafybeihngw4os7fg6xzthb7cpydfiavpufkg746khabkc...
# 9  bafybeifxdk6cm6xecwyq7euxojpiuao66ob3nkbjjpxhh...
#
#                          created             type         scope  \
# 0  2022-03-24T16:55:42.506+00:00        form-data  audiocentive
# 1  2022-03-24T16:51:43.101+00:00        form-data  audiocentive
# 2  2022-03-22T17:04:21.124+00:00        form-data  audiocentive
# 3   2022-03-21T15:57:38.91+00:00  application/car       session
# 4  2022-03-20T23:33:25.689+00:00        form-data  audiocentive
# 5  2022-03-09T06:19:39.874+00:00        form-data  audiocentive
# 6   2022-03-09T04:10:04.14+00:00       image/jpeg  audiocentive
# 7  2022-03-09T04:03:21.867+00:00        form-data  audiocentive
# 8  2022-03-09T03:16:57.338+00:00        directory  audiocentive
# 9  2022-03-09T02:31:11.692+00:00        form-data  audiocentive
#
#                               files      size  \
# 0                                []     23597
# 1                                []     24858
# 2                                []   6455453
# 3                                []      2119
# 4                                []       895
# 5                                []     10060
# 6                                []   5245419
# 7                                []   2086898
# 8  [{'name': 'myfile', 'type': ''}]  42725396
# 9                                []  42725615
#
#                                                  pin  \
# 0  {'cid': 'bafkreiesap4b4a4xgvfxhsz6hdza7atezclk...
# 1  {'cid': 'bafkreief472lhr6b54baq4oansiwor4ed2te...
# 2  {'cid': 'bafybeif6gdxdpleultgqobk65dhy6gvnozu2...
# 3  {'cid': 'bafkreifhvosw3d4agsnduodmyupqdngsjddd...
# 4  {'cid': 'bafkreie2muwin7je3fc5uaepmc6jwt6mv6mf...
# 5  {'cid': 'bafkreicwnshhm5jg6uvf6lvfcebohrijpyb6...
# 6  {'cid': 'bafybeibjwiqi4c7yebpobalni3eijfgkgwmi...
# 7  {'cid': 'bafybeif36uqfqj5on23qfdl3nglc7ncgcbnz...
# 8  {'cid': 'bafybeihngw4os7fg6xzthb7cpydfiavpufkg...
# 9  {'cid': 'bafybeifxdk6cm6xecwyq7euxojpiuao66ob3...
#
#                                                deals
# 0  [{'status': 'active', 'lastChanged': '2022-03-...
# 1  [{'status': 'active', 'lastChanged': '2022-03-...
# 2  [{'status': 'active', 'lastChanged': '2022-03-...
# 3  [{'status': 'active', 'lastChanged': '2022-03-...
# 4  [{'status': 'active', 'lastChanged': '2022-03-...
# 5  [{'status': 'active', 'lastChanged': '2022-03-...
# 6  [{'status': 'active', 'lastChanged': '2022-03-...
# 7  [{'status': 'active', 'lastChanged': '2022-03-...
# 8  [{'status': 'active', 'lastChanged': '2022-03-...
# 9  [{'status': 'active', 'lastChanged': '2022-03-...

# %%
from storage.ipfs import IPFS

ipfs = IPFS()

# %%
response,log = ipfs.get_file("QmWAQjxm6CKaAjHjwPSqWmN8RMecuHS1bxEufqCNVSq96e",local_node=False)
# Out:
# Retrieved file hash QmWAQjxm6CKaAjHjwPSqWmN8RMecuHS1bxEufqCNVSq96e from https://dweb.link Response 200

# %%
read_file(response.content)
# Out:
#         Timestamp Token  Borrowing Rate  Deposit Rate  Borrow Volume  \
# 0      1609471800   DAI        0.073195      0.050982   1.069964e+09
# 1      1609471800  USDC        0.087046      0.066993   7.285430e+08
# 2      1609471800  USDT        0.099588      0.077548   6.430536e+07
# 3      1609471800   ETH        0.022952      0.000489   3.055365e+04
# 4      1609473600   DAI        0.073101      0.050912   1.069961e+09
# ...           ...   ...             ...           ...            ...
# 66789  1639539000   ETH        0.027215      0.000761   5.316478e+04
# 66790  1639540800   ETH        0.027214      0.000761   5.316480e+04
# 66791  1639542600   ETH        0.027214      0.000761   5.316488e+04
# 66792  1639544400   ETH        0.027226      0.000764   5.316501e+04
# 66793  1639546200   ETH        0.027229      0.000764   5.316508e+04
#
#        Supply Volume
# 0       6.196481e+10
# 1       4.063042e+10
# 2       3.696225e+09
# 3       5.663257e+07
# 4       6.197050e+10
# ...              ...
# 66789   7.481990e+07
# 66790   7.482188e+07
# 66791   7.482482e+07
# 66792   7.461519e+07
# 66793   7.456406e+07
#
# [66794 rows x 6 columns]

# %%
data = {"ipfsPinHash": "QmWAQjxm6CKaAjHjwPSqWmN8RMecuHS1bxEufqCNVSq96e",
        "name": "compound.csv",
        "keyvalues": {
            "DAO":"DeepFi",
            "Data":"Compound",
            "Task":"[BorrowRate,DepositRate]"
        }
         }

pinata.edit_hash(pinata_creds,"QmWAQjxm6CKaAjHjwPSqWmN8RMecuHS1bxEufqCNVSq96e","compound.csv",pinataMetaData=data)
# Out:
# 500

# %%
data = {"ipfsPinHash": "QmWAQjxm6CKaAjHjwPSqWmN8RMecuHS1bxEufqCNVSq96e",
        "name": "compound.csv",
        "keyvalues": {
            "DAO":"DeepFi",
            "Data":"Compound",
            "Task":None
        }
       }

pinata.upload_file(pinata_creds,"dataset/sample/compound.csv","compound.csv",pinataMetadata=data)
# Out:
# ({'IpfsHash': 'QmWAQjxm6CKaAjHjwPSqWmN8RMecuHS1bxEufqCNVSq96e',
#   'PinSize': 5985301,
#   'Timestamp': '2022-03-29T17:28:48.909Z'},
#  200)
