# %% [markdown]
# # Dynamically pin and unpin from providers
# ## Benefit
# * Data Scientists can dynamically change pinning providers
# * Data Scientists don't rely on one IPFS gateway, but can use many

# %% [markdown]
# ## Importing libraries

# %%
#main protocol
from storage.ipfs import IPFS

#pinning providers
from storage.nftstorage import NFTStorage
from storage.pinataV1 import PinataV1


#helpers
from helpers.helper import read_file
import pandas as pd

# %%
#Load in credentials - Not an optimal solution and can investigate a better solution with something like Lit Protocol

nft_storage = NFTStorage()
nft_storage_creds = nft_storage.get_creds()
ipfs = IPFS()
pinata = PinataV1()
pinata_creds = pinata.get_creds()

# %%
#Upload to nft storage, this is called pinning or simplicity, NFTstorage actually facilitates the pinning deals under the hood inteh deals section
#the response returns a cid and what filecoin deals have been made to pin your file.

response, status_code = nft_storage.upload_file(nft_storage_creds,"dataset/ens_airdrop.json")

pd.DataFrame(response)
# Out:
#            ok                                              value
# cid      True  bafybeiek3lyobn6lgt46bj5pf4cyd7qcj7o4umkeyg7rv...
# created  True                      2022-03-09T02:21:11.461+00:00
# deals    True  [{'status': 'active', 'lastChanged': '2022-03-...
# files    True                                                 []
# name     True                 Upload at 2022-05-17T18:04:01.593Z
# pin      True  {'cid': 'bafybeiek3lyobn6lgt46bj5pf4cyd7qcj7o4...
# scope    True                                       audiocentive
# size     True                                           42725339
# type     True                                          form-data

# %%
#Pin to pinata for redundency
pinata.pin(pinata_creds,response["value"]["cid"],fn="ens_airdrop.json")
# Out:
# ({'id': 'f9878627-7086-4018-864c-6bb26e5b553d',
#   'ipfsHash': 'bafybeiek3lyobn6lgt46bj5pf4cyd7qcj7o4umkeyg7rvwkpjfr6tsj3ye',
#   'status': 'prechecking',
#   'name': 'ens_airdrop.json'},
#  200)

# %%
#Check the status of the pinning job, pin policy will show what regions the file is available in
params = {"hashContains":"DESC","status":None,"prechecking":None,
          "searching":None,"retrieving":None,
          "expired":None,"over_free_limit":None,
          "over_max_size":None,"invalid_object":None,
          "bad_host_node":None,"ipfs_pin_hash":response["value"]["cid"],
          "limit":None,"offset":None,"metadata[name]":None,
          "metadatakeyvalues":"keyvalues"
         }

pinata.get_pinned_jobs(pinata_creds,params)
# Out:
# ({'count': 1,
#   'rows': [{'id': 'f9878627-7086-4018-864c-6bb26e5b553d',
#     'ipfs_pin_hash': 'bafybeiek3lyobn6lgt46bj5pf4cyd7qcj7o4umkeyg7rvwkpjfr6tsj3ye',
#     'date_queued': '2022-05-17T18:04:03.795Z',
#     'name': 'ens_airdrop.json',
#     'status': 'prechecking',
#     'keyvalues': {},
#     'host_nodes': None,
#     'pin_policy': {'regions': [{'id': 'NYC1', 'desiredReplicationCount': 1}],
#      'version': 1}}]},
#  200)

# %%
"""
Query Parameters = params

hashContains: (string) - Filter on alphanumeric characters inside of pin hashes. Hashes which do not include the characters passed in will not be returned.

pinStart: (must be in ISO_8601 format) - Exclude pin records that were pinned before the passed in "pinStart" datetime.

pinEnd: (must be in ISO_8601 format) - Exclude pin records that were pinned after the passed in "pinEnd" datetime.

unpinStart: (must be in ISO_8601 format) - Exclude pin records that were unpinned before the passed in "unpinStart" datetime.

unpinEnd: (must be in ISO_8601 format) - Exclude pin records that were unpinned after the passed in "unpinEnd" datetime.

pinSizeMin: (integer) - The minimum byte size that pin record you're looking for can have

pinSizeMax: (integer) - The maximum byte size that pin record you're looking for can have

status: (string) -
    * Pass in "all" for both pinned and unpinned records
    * Pass in "pinned" for just pinned records (hashes that are currently pinned)
    * Pass in "unpinned" for just unpinned records (previous hashes that are no longer being pinned on pinata)

pageLimit: (integer) - This sets the amount of records that will be returned per API response. (Max 1000)

pageOffset: (integer) - This tells the API how far to offset the record responses. For example, 
if there's 30 records that match your query, and you passed in a pageLimit of 10, providing a pageOffset of 10 would return records 11-20.
"""

#Get all pinned files to unpin and then pin in NFT Storage
#If pageLimit == None then defaults to most recent 10

params = {"hasContains":"b","pinStart":None,
          "pinEnd":None,"unpinStart":None,
          "unpinEnd":None,"pinSizeMin":None,
          "pinSizeMax":None,"status":None,
          "pageLimit":100,"pageOffset":None,
         }

pf,status = pinata.get_pinned_files(pinata_creds,params)
df_pinata = pd.DataFrame(pf["rows"])

df_pinata.drop_duplicates(["ipfs_pin_hash"])
# Out:
#                                       id  \
# 0   aeeedbc4-b9b4-4db8-bdf6-72026692bb3f
# 1   60e6a6ea-87bb-4d46-8118-28cdd2fc719f
# 2   2fc660d2-00b8-45a2-9f53-525ad5de4218
# 3   2df4c71a-8666-4710-8306-0232c38102df
# 4   506ae9a4-dc1d-4a62-b6e0-290fef1bfae9
# 5   653c4f52-8a86-443d-bf13-dee9eb7e1e63
# 6   ed61bba0-bef6-4afd-a225-162ac9360294
# 7   4799e80f-ff91-4992-8854-27ed0d2db1ac
# 8   ac6bf429-d7e5-45e8-b2c9-30919b01a26b
# 9   3bb6cefd-d920-4e0a-b533-72af30cd6dd5
# 10  dcb977a9-a9b9-4e0c-9d30-96217a355d5a
# 11  4595e6ea-ee3c-471f-8854-91b83b119172
# 12  60f63d32-cfc2-4cab-a1b5-4da5407f51b5
# 13  fb962d59-4309-4413-b0ec-ab1c0bb5d37e
# 14  7efe8f76-588f-4875-b3b5-2a056cfdb37d
# 15  6416948c-3e84-46f4-b268-148f01bcbadb
# 16  13a665ef-410f-4a64-9723-07e5d3ac8c8a
# 17  06e80ae7-586d-44a8-b24d-3addeb0798d6
# 18  e4b923bd-7cb5-4e3d-9985-eced1483f1ce
# 19  5eee7375-c956-4fb6-bc25-17a99813469d
# 20  8f8f17b9-99e8-48c2-9ddb-090e16f1a1e8
# 21  14eb7596-1a88-441a-aee8-a83f4c9028b3
# 22  eb01eaa0-bf8b-40dd-80a4-9a1cac23143d
# 25  b1065f06-c4df-4b7f-8861-0abe549c82c5
# 26  b7db077e-5ed9-4c93-9b42-456ce21faefc
# 27  a6566f26-87c3-41ac-b47e-8fe2aa879a31
# 28  01b08b66-0ae1-43f1-b1cb-be6e16939e67
# 29  f5b03a17-cb17-4b91-8919-8b3ffefed5e6
# 30  d9dd43cc-188d-4ad6-9068-043f9b723ede
# 31  4ae49564-1a8c-4289-b666-399abe30587d
# 32  d073ef50-b94c-48c4-9f1f-1e3771a60207
# 33  01ed6d7b-f1c1-4a1c-babd-bbb0c9702d8c
# 34  06d47e3d-cdac-4b06-aafd-ae3f7d214922
# 57                      None
# 58                      None
# 59                      None
# 60                      None
# 61                      None
# 62                      None
# 63                      None
# 64                      None
# 65                      None
# 66                      None
# 67                      None
# 68                      None
# 70                      None
# 71                      None
# 74  2022-04-30T03:57:12.067Z
# 75                      None
# 76                      None
#
#                                              metadata  \
# 0   {'name': 'DefiSquad_Compound_StableCoin_Borrow...
# 1                      {'name': '_', 'keyvalues': {}}
# 2                      {'name': '_', 'keyvalues': {}}
# 3                      {'name': '_', 'keyvalues': {}}
# 4                      {'name': '_', 'keyvalues': {}}
# 5                      {'name': '_', 'keyvalues': {}}
# 6                      {'name': '_', 'keyvalues': {}}
# 7   {'name': '_', 'keyvalues': {'library': 'Sklear...
# 8   {'name': '_', 'keyvalues': {'library': 'Sklear...
# 9   {'name': '_', 'keyvalues': {'library': 'Sklear...
# 10  {'name': '_', 'keyvalues': {'library': 'Sklear...
# 11  {'name': '_', 'keyvalues': {'library': 'Sklear...
# 12  {'name': '_', 'keyvalues': {'library': 'Sklear...
# 13  {'name': '_', 'keyvalues': {'library': 'Sklear...
# 14  {'name': '_', 'keyvalues': {'library': 'Sklear...
# 15  {'name': '_', 'keyvalues': {'library': 'Sklear...
# 16  {'name': '_', 'keyvalues': {'library': 'Sklear...
# 17  {'name': '_', 'keyvalues': {'library': 'Sklear...
# 18  {'name': '_', 'keyvalues': {'library': 'Sklear...
# 19  {'name': '_', 'keyvalues': {'library': 'Sklear...
# 20  {'name': '_', 'keyvalues': {'library': 'Sklear...
# 21  {'name': '_', 'keyvalues': {'library': 'Sklear...
# 22  {'name': '_', 'keyvalues': {'library': 'Sklear...
# 25                     {'name': '_', 'keyvalues': {}}
# 26                     {'name': '_', 'keyvalues': {}}
# 27                     {'name': '_', 'keyvalues': {}}
# 28                     {'name': '_', 'keyvalues': {}}
# 29                     {'name': '_', 'keyvalues': {}}
# 30                     {'name': '_', 'keyvalues': {}}
# 31                     {'name': '_', 'keyvalues': {}}
# 32                     {'name': '_', 'keyvalues': {}}
# 33                     {'name': '_', 'keyvalues': {}}
# 34                     {'name': '_', 'keyvalues': {}}
# 35                     {'name': '_', 'keyvalues': {}}
# 36                     {'name': '_', 'keyvalues': {}}
# 39                     {'name': '_', 'keyvalues': {}}
# 40                     {'name': '_', 'keyvalues': {}}
# 43                     {'name': '_', 'keyvalues': {}}
# 44                     {'name': '_', 'keyvalues': {}}
# 54  {'name': 'RandomForestClassifier_5_7.pkl', 'ke...
# 55  {'name': 'AdaBoostClassifier_5_7.pkl', 'keyval...
# 56  {'name': 'RandomForestClassifierstratified_5_7...
# 57  {'name': 'GradientBoostingClassifierstratified...
# 58                     {'name': '_', 'keyvalues': {}}
# 59                     {'name': '_', 'keyvalues': {}}
# 60                    {'name': None, 'keyvalues': {}}
# 61                    {'name': None, 'keyvalues': {}}
# 62                    {'name': None, 'keyvalues': {}}
# 63                    {'name': None, 'keyvalues': {}}
# 64                    {'name': None, 'keyvalues': {}}
# 65                    {'name': None, 'keyvalues': {}}
# 66                    {'name': None, 'keyvalues': {}}
# 67                    {'name': None, 'keyvalues': {}}
# 68                    {'name': None, 'keyvalues': {}}
# 70  {'name': '_', 'keyvalues': {'library': 'Sklear...
# 71  {'name': '_', 'keyvalues': {'library': 'Sklear...
# 74                    {'name': None, 'keyvalues': {}}
# 75                    {'name': None, 'keyvalues': {}}
# 76                    {'name': None, 'keyvalues': {}}
#
#                                               regions
# 0   [{'regionId': 'NYC1', 'currentReplicationCount...
# 1   [{'regionId': 'NYC1', 'currentReplicationCount...
# 2   [{'regionId': 'NYC1', 'currentReplicationCount...
# 3   [{'regionId': 'NYC1', 'currentReplicationCount...
# 4   [{'regionId': 'NYC1', 'currentReplicationCount...
# 5   [{'regionId': 'NYC1', 'currentReplicationCount...
# 6   [{'regionId': 'NYC1', 'currentReplicationCount...
# 7   [{'regionId': 'NYC1', 'currentReplicationCount...
# 8   [{'regionId': 'NYC1', 'currentReplicationCount...
# 9   [{'regionId': 'NYC1', 'currentReplicationCount...
# 10  [{'regionId': 'NYC1', 'currentReplicationCount...
# 11  [{'regionId': 'NYC1', 'currentReplicationCount...
# 12  [{'regionId': 'NYC1', 'currentReplicationCount...
# 13  [{'regionId': 'NYC1', 'currentReplicationCount...
# 14  [{'regionId': 'NYC1', 'currentReplicationCount...
# 15  [{'regionId': 'NYC1', 'currentReplicationCount...
# 16  [{'regionId': 'NYC1', 'currentReplicationCount...
# 17  [{'regionId': 'NYC1', 'currentReplicationCount...
# 18  [{'regionId': 'NYC1', 'currentReplicationCount...
# 19  [{'regionId': 'NYC1', 'currentReplicationCount...
# 20  [{'regionId': 'NYC1', 'currentReplicationCount...
# 21  [{'regionId': 'NYC1', 'currentReplicationCount...
# 22  [{'regionId': 'NYC1', 'currentReplicationCount...
# 25  [{'regionId': 'NYC1', 'currentReplicationCount...
# 26  [{'regionId': 'NYC1', 'currentReplicationCount...
# 27  [{'regionId': 'NYC1', 'currentReplicationCount...
# 28  [{'regionId': 'NYC1', 'currentReplicationCount...
# 29  [{'regionId': 'NYC1', 'currentReplicationCount...
# 30  [{'regionId': 'NYC1', 'currentReplicationCount...
# 31  [{'regionId': 'NYC1', 'currentReplicationCount...
# 32  [{'regionId': 'NYC1', 'currentReplicationCount...
# 33  [{'regionId': 'NYC1', 'currentReplicationCount...
# 34  [{'regionId': 'NYC1', 'currentReplicationCount...
# 35  [{'regionId': 'NYC1', 'currentReplicationCount...
# 36  [{'regionId': 'NYC1', 'currentReplicationCount...
# 39  [{'regionId': 'NYC1', 'currentReplicationCount...
# 40  [{'regionId': 'NYC1', 'currentReplicationCount...
# 43  [{'regionId': 'NYC1', 'currentReplicationCount...
# 44  [{'regionId': 'NYC1', 'currentReplicationCount...
# 54  [{'regionId': 'NYC1', 'currentReplicationCount...
# 55  [{'regionId': 'NYC1', 'currentReplicationCount...
# 56  [{'regionId': 'NYC1', 'currentReplicationCount...
# 57  [{'regionId': 'NYC1', 'currentReplicationCount...
# 58  [{'regionId': 'NYC1', 'currentReplicationCount...
# 59  [{'regionId': 'NYC1', 'currentReplicationCount...
# 60  [{'regionId': 'NYC1', 'currentReplicationCount...
# 61  [{'regionId': 'NYC1', 'currentReplicationCount...
# 62  [{'regionId': 'NYC1', 'currentReplicationCount...
# 63  [{'regionId': 'NYC1', 'currentReplicationCount...
# 64  [{'regionId': 'NYC1', 'currentReplicationCount...
# 65  [{'regionId': 'NYC1', 'currentReplicationCount...
# 66  [{'regionId': 'NYC1', 'currentReplicationCount...
# 67  [{'regionId': 'NYC1', 'currentReplicationCount...
# 68  [{'regionId': 'NYC1', 'currentReplicationCount...
# 70  [{'regionId': 'NYC1', 'currentReplicationCount...
# 71  [{'regionId': 'NYC1', 'currentReplicationCount...
# 74  [{'regionId': 'NYC1', 'currentReplicationCount...
# 75  [{'regionId': 'NYC1', 'currentReplicationCount...
# 76  [{'regionId': 'NYC1', 'currentReplicationCount...

# %%
df_pinata.query('ipfs_pin_hash == "QmWAQjxm6CKaAjHjwPSqWmN8RMecuHS1bxEufqCNVSq96e"')["metadata"]
# Out:
# Series([], Name: metadata, dtype: object)

# %%
#Make a CID dictionary to pin these files to NFT Storage

df_pinata["filename"]=df_pinata["metadata"].apply(lambda x: x["name"])
file_dict = df_pinata[["filename","ipfs_pin_hash"]].drop_duplicates(subset="filename").set_index("filename")

file_dict
# Out:
#                                                                                         ipfs_pin_hash
# filename
# DefiSquad_Compound_StableCoin_BorrowingStrategy...  bafkreidqulmh3jp2oeea2fth7q3ilx3y456magfqhnj22...
# _                                                   bafybeibpuxulnxkxyamy67y6ybyc4mnyjoaddjuxuuuhl...
# RandomForestClassifier_5_7.pkl                         QmUWHKNi9WLQPbD9sHFjYr5BrtyQ2ZVSLMrrGD6tmCKbZQ
# AdaBoostClassifier_5_7.pkl                             QmPyjZ1dpz2bbHxxC8F959QGQ3qPPw5PPAeJWZ1LJ6NCtw
# RandomForestClassifierstratified_5_7.pkl               Qmbs43cCcWUYtXnq3EAdYk2Sj2oj26KJtXtYNz9cbD7W3U
# GradientBoostingClassifierstratified_5_7.pkl           QmQF2ntZSTS5gZ94HqbXopdwzbdZBRVEW6sxgKYsDu9XGT
# None                                                bafkreib6uzvfbv43ioa5eflfozyaccnv3qfmkc5vhwccw...

# %%
#NFT Storage Files

response = nft_storage.get_all_files(nft_storage_creds)

nft_storage_files = pd.DataFrame(response.json()["value"])

nft_storage_files
# Out:
#                                                  cid  \
# 0  bafkreidqulmh3jp2oeea2fth7q3ilx3y456magfqhnj22...
# 1  bafybeibpuxulnxkxyamy67y6ybyc4mnyjoaddjuxuuuhl...
# 2  bafkreibddlkj4ze3sogwp7cahtxvke7yggteayjkaaavd...
# 3  bafkreie2qucmecsyc3q7hhrccsif3lzsdu7zub3fy3zsp...
# 4  bafkreiaxeimcjute2c6ecay6tulotm7nehgnhaolp4yca...
# 5  bafkreicxtodg6u6qs23g6lbzyxkrvhua3bwu2ngz45ibt...
# 6  bafybeict3mhosmy3kdgoslpauxbadciaelmcdkrnopwaf...
# 7  bafybeib6bki5chp33q2un4rcqxbl5lozwnjgzrkmzgmy7...
# 8  bafkreib6tjtu4yrzrxazxd2sbyi6hro2h2ho3ntvgl3q6...
# 9  bafkreieukwyd35jpv5pvfbb5bv2qowzzj3d5qakcuzld4...
#
#                          created       type         scope files    size  \
# 0  2022-05-04T16:20:32.234+00:00  form-data  audiocentive    []  210533
# 1  2022-05-02T16:09:27.062+00:00  form-data  audiocentive    []  264554
# 2   2022-05-02T16:09:04.33+00:00  form-data  audiocentive    []    1698
# 3  2022-05-02T16:07:46.353+00:00  form-data  audiocentive    []   35270
# 4   2022-05-02T16:07:27.46+00:00  form-data  audiocentive    []    1698
# 5  2022-05-01T14:48:58.689+00:00  form-data  audiocentive    []   42739
# 6  2022-05-01T14:47:15.352+00:00  form-data  audiocentive    []  285760
# 7  2022-05-01T05:17:49.636+00:00  form-data  audiocentive    []  268545
# 8  2022-05-01T05:17:29.324+00:00  form-data  audiocentive    []    1698
# 9  2022-05-01T05:16:25.805+00:00  form-data  audiocentive    []   35270
#
#                                  name  \
# 0  Upload at 2022-05-06T16:04:57.297Z
# 1  Upload at 2022-05-02T16:09:27.062Z
# 2  Upload at 2022-05-02T16:09:04.330Z
# 3  Upload at 2022-05-02T16:07:46.353Z
# 4  Upload at 2022-05-02T16:07:27.460Z
# 5  Upload at 2022-05-01T16:13:14.268Z
# 6  Upload at 2022-05-01T16:12:46.559Z
# 7  Upload at 2022-05-01T05:17:49.636Z
# 8  Upload at 2022-05-01T05:17:29.324Z
# 9  Upload at 2022-05-01T05:16:25.805Z
#
#                                                  pin  \
# 0  {'cid': 'bafkreidqulmh3jp2oeea2fth7q3ilx3y456m...
# 1  {'cid': 'bafybeibpuxulnxkxyamy67y6ybyc4mnyjoad...
# 2  {'cid': 'bafkreibddlkj4ze3sogwp7cahtxvke7yggte...
# 3  {'cid': 'bafkreie2qucmecsyc3q7hhrccsif3lzsdu7z...
# 4  {'cid': 'bafkreiaxeimcjute2c6ecay6tulotm7nehgn...
# 5  {'cid': 'bafkreicxtodg6u6qs23g6lbzyxkrvhua3bwu...
# 6  {'cid': 'bafybeict3mhosmy3kdgoslpauxbadciaelmc...
# 7  {'cid': 'bafybeib6bki5chp33q2un4rcqxbl5lozwnjg...
# 8  {'cid': 'bafkreib6tjtu4yrzrxazxd2sbyi6hro2h2ho...
# 9  {'cid': 'bafkreieukwyd35jpv5pvfbb5bv2qowzzj3d5...
#
#                                                deals
# 0  [{'status': 'active', 'lastChanged': '2022-05-...
# 1  [{'status': 'active', 'lastChanged': '2022-05-...
# 2  [{'status': 'active', 'lastChanged': '2022-05-...
# 3  [{'status': 'active', 'lastChanged': '2022-05-...
# 4  [{'status': 'active', 'lastChanged': '2022-05-...
# 5  [{'status': 'active', 'lastChanged': '2022-05-...
# 6  [{'status': 'active', 'lastChanged': '2022-05-...
# 7  [{'status': 'active', 'lastChanged': '2022-05-...
# 8  [{'status': 'active', 'lastChanged': '2022-05-...
# 9  [{'status': 'active', 'lastChanged': '2022-05-...

# %% [markdown]
# # Compare Pinata Files to NFT Storage to upload the outstanding files

# %%
pinata_pinned = file_dict["ipfs_pin_hash"].to_list()

nft_storage_pinned = nft_storage_files["cid"].to_list()

outstanding_hashs = set(nft_storage_pinned).difference(pinata_pinned)
outstanding_hashs
# Out:
# {'bafkreiaxeimcjute2c6ecay6tulotm7nehgnhaolp4ycayyvnkxly6jy3u',
#  'bafkreib6tjtu4yrzrxazxd2sbyi6hro2h2ho3ntvgl3q6lsmwbn3b775hy',
#  'bafkreibddlkj4ze3sogwp7cahtxvke7yggteayjkaaavdcvotx3wdsexgy',
#  'bafkreicxtodg6u6qs23g6lbzyxkrvhua3bwu2ngz45ibtubvosby3a2uua',
#  'bafkreie2qucmecsyc3q7hhrccsif3lzsdu7zub3fy3zspzggyrfjizjbeu',
#  'bafkreieukwyd35jpv5pvfbb5bv2qowzzj3d5qakcuzld46zofvgxpzkfza',
#  'bafybeib6bki5chp33q2un4rcqxbl5lozwnjgzrkmzgmy7jmu2fyqygbaye',
#  'bafybeict3mhosmy3kdgoslpauxbadciaelmcdkrnopwaf6osszuzgdvbwq'}

# %%
#Pin oustanding hashes to pinata
for cid in outstanding_hashs:
    
    pinata.pin(pinata_creds,cid)

# %%
#Pin oustanding hashes to pinata

for cid in outstanding_hashs:
    pinata.unpin(pinata_creds,cid)
    nft_storage.unpin(nft_storage_creds,cid)

# %% [markdown]
# # As you can see all the CIDs with a Q were removed. Q is V1 and b is V2

# %%
response = nft_storage.get_all_files(nft_storage_creds)

nft_storage_files = pd.DataFrame(response.json()["value"])

nft_storage_files
# Out:
#                                                  cid  \
# 0  bafkreidqulmh3jp2oeea2fth7q3ilx3y456magfqhnj22...
# 1  bafybeibpuxulnxkxyamy67y6ybyc4mnyjoaddjuxuuuhl...
# 2  bafkreihwhpx44sxz3qmaghrwmnhdbnjc54jqdnh3xjlck...
# 3  bafkreihmgzwftdylufh7sjfcvjydmbud22x6o5ezq5g74...
# 4  bafkreibaxy52fmi3iggbcks7bd6soedzbm7ljjy7wmqym...
# 5  bafkreibhkbtsouxafk6zklajriu4u5furd4dy6fhfrtho...
# 6  bafkreiea3my7e6atl4jupmbeq6wf6uaglj6abzqnx7s5g...
# 7  bafybeig4lb73hzccn7srdpw5doucugp3bizee64cyfrt5...
# 8  bafkreicubfweo52qyyqzgzudjwz57msnuhon7xawxm2i5...
# 9  bafkreia4rvpegipqja42ytgersqkxrsthzzhqmg4x4axq...
#
#                          created       type         scope files    size  \
# 0  2022-05-04T16:20:32.234+00:00  form-data  audiocentive    []  210533
# 1  2022-05-02T16:09:27.062+00:00  form-data  audiocentive    []  264554
# 2  2022-05-01T05:16:08.837+00:00  form-data  audiocentive    []    1698
# 3  2022-05-01T05:05:51.314+00:00  form-data  audiocentive    []  257879
# 4  2022-05-01T05:05:31.413+00:00  form-data  audiocentive    []    1698
# 5  2022-05-01T05:04:19.429+00:00  form-data  audiocentive    []   35270
# 6  2022-05-01T05:04:04.507+00:00  form-data  audiocentive    []    1698
# 7    2022-04-30T23:52:15.9+00:00  form-data  audiocentive    []  269357
# 8  2022-04-30T23:51:57.864+00:00  form-data  audiocentive    []    1698
# 9  2022-04-30T23:50:50.929+00:00  form-data  audiocentive    []   35270
#
#                                  name  \
# 0  Upload at 2022-05-06T16:04:57.297Z
# 1  Upload at 2022-05-02T16:09:27.062Z
# 2  Upload at 2022-05-01T05:16:08.837Z
# 3  Upload at 2022-05-01T05:05:51.314Z
# 4  Upload at 2022-05-01T05:05:31.413Z
# 5  Upload at 2022-05-01T05:04:19.429Z
# 6  Upload at 2022-05-01T05:04:04.507Z
# 7  Upload at 2022-04-30T23:52:15.900Z
# 8  Upload at 2022-04-30T23:51:57.864Z
# 9  Upload at 2022-04-30T23:50:50.929Z
#
#                                                  pin  \
# 0  {'cid': 'bafkreidqulmh3jp2oeea2fth7q3ilx3y456m...
# 1  {'cid': 'bafybeibpuxulnxkxyamy67y6ybyc4mnyjoad...
# 2  {'cid': 'bafkreihwhpx44sxz3qmaghrwmnhdbnjc54jq...
# 3  {'cid': 'bafkreihmgzwftdylufh7sjfcvjydmbud22x6...
# 4  {'cid': 'bafkreibaxy52fmi3iggbcks7bd6soedzbm7l...
# 5  {'cid': 'bafkreibhkbtsouxafk6zklajriu4u5furd4d...
# 6  {'cid': 'bafkreiea3my7e6atl4jupmbeq6wf6uaglj6a...
# 7  {'cid': 'bafybeig4lb73hzccn7srdpw5doucugp3bize...
# 8  {'cid': 'bafkreicubfweo52qyyqzgzudjwz57msnuhon...
# 9  {'cid': 'bafkreia4rvpegipqja42ytgersqkxrsthzzh...
#
#                                                deals
# 0  [{'status': 'active', 'lastChanged': '2022-05-...
# 1  [{'status': 'active', 'lastChanged': '2022-05-...
# 2  [{'status': 'active', 'lastChanged': '2022-05-...
# 3  [{'status': 'active', 'lastChanged': '2022-05-...
# 4  [{'status': 'active', 'lastChanged': '2022-05-...
# 5  [{'status': 'active', 'lastChanged': '2022-05-...
# 6  [{'status': 'active', 'lastChanged': '2022-05-...
# 7  [{'status': 'active', 'lastChanged': '2022-05-...
# 8  [{'status': 'active', 'lastChanged': '2022-05-...
# 9  [{'status': 'active', 'lastChanged': '2022-05-...

# %%
from storage.ipfs import IPFS

ipfs = IPFS()

# %%
response,log = ipfs.get_file("QmWAQjxm6CKaAjHjwPSqWmN8RMecuHS1bxEufqCNVSq96e",local_node=False)
# Out:
# Retrieved file hash QmWAQjxm6CKaAjHjwPSqWmN8RMecuHS1bxEufqCNVSq96e from https://dweb.link Response 200

# %%
read_file(response.content)
# Out:
#         Timestamp Token  Borrowing Rate  Deposit Rate  Borrow Volume  \
# 0      1609471800   DAI        0.073195      0.050982   1.069964e+09
# 1      1609471800  USDC        0.087046      0.066993   7.285430e+08
# 2      1609471800  USDT        0.099588      0.077548   6.430536e+07
# 3      1609471800   ETH        0.022952      0.000489   3.055365e+04
# 4      1609473600   DAI        0.073101      0.050912   1.069961e+09
# ...           ...   ...             ...           ...            ...
# 66789  1639539000   ETH        0.027215      0.000761   5.316478e+04
# 66790  1639540800   ETH        0.027214      0.000761   5.316480e+04
# 66791  1639542600   ETH        0.027214      0.000761   5.316488e+04
# 66792  1639544400   ETH        0.027226      0.000764   5.316501e+04
# 66793  1639546200   ETH        0.027229      0.000764   5.316508e+04
#
#        Supply Volume
# 0       6.196481e+10
# 1       4.063042e+10
# 2       3.696225e+09
# 3       5.663257e+07
# 4       6.197050e+10
# ...              ...
# 66789   7.481990e+07
# 66790   7.482188e+07
# 66791   7.482482e+07
# 66792   7.461519e+07
# 66793   7.456406e+07
#
# [66794 rows x 6 columns]

# %%
data = {"ipfsPinHash": "QmWAQjxm6CKaAjHjwPSqWmN8RMecuHS1bxEufqCNVSq96e",
        "name": "compound.csv",
        "keyvalues": {
            "DAO":"DeepFi",
            "Data":"Compound",
            "Task":"[BorrowRate,DepositRate]"
        }
         }

pinata.edit_hash(pinata_creds,"QmWAQjxm6CKaAjHjwPSqWmN8RMecuHS1bxEufqCNVSq96e","compound.csv",pinataMetaData=data)
# Out:
# 200

# %%
data = {"ipfsPinHash": "QmWAQjxm6CKaAjHjwPSqWmN8RMecuHS1bxEufqCNVSq96e",
        "name": "compound.csv",
        "keyvalues": {
            "DAO":"DeepFi",
            "Data":"Compound",
            "Task":None
        }
       }

pinata.upload_file(pinata_creds,"dataset/compound.csv","compound.csv",pinataMetadata=data)
# Out:
# ({'IpfsHash': 'QmWAQjxm6CKaAjHjwPSqWmN8RMecuHS1bxEufqCNVSq96e',
#   'PinSize': 5985301,
#   'Timestamp': '2022-03-29T17:28:48.909Z',
#   'isDuplicate': True},
#  200)
